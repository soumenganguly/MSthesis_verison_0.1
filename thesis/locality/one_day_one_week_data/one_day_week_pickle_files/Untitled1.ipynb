# %%
import pickle

# %%
a=open('PUL_PDF_oneweek.pkl','rb')

# %%
p=pickle.load(a)

# %%
pdf_pop_s1 = [p[word][0] for word in p]
pdf_pop_s2 = [p[word][1] for word in p]

# %%
pul_pop
# Out:
# [7,
#  14,
#  0,
#  22,
#  21,
#  3,
#  6,
#  1,
#  1,
#  0,
#  22,
#  159,
#  12,
#  2,
#  4,
#  14,
#  10,
#  2,
#  100,
#  5,
#  2,
#  10,
#  5,
#  1,
#  4,
#  3,
#  6,
#  14,
#  2,
#  0,
#  13,
#  2,
#  25,
#  10,
#  0,
#  4,
#  39,
#  0,
#  4,
#  4,
#  2,
#  15,
#  35,
#  0,
#  7,
#  0,
#  4,
#  5,
#  67,
#  0,
#  8,
#  11,
#  6,
#  1,
#  0,
#  0,
#  9,
#  2,
#  0,
#  0,
#  0,
#  13,
#  6,
#  0,
#  14,
#  4,
#  0,
#  2,
#  6,
#  25,
#  0,
#  11,
#  10,
#  7,
#  3,
#  9,
#  0,
#  0,
#  40,
#  2,
#  2,
#  15,
#  2,
#  17,
#  2,
#  3,
#  14,
#  0,
#  0,
#  10,
#  10,
#  0,
#  2,
#  0,
#  3,
#  24,
#  16,
#  4,
#  2,
#  26,
#  0,
#  1,
#  4,
#  2,
#  15,
#  9,
#  4,
#  42,
#  3,
#  0,
#  3,
#  26,
#  36,
#  0,
#  24,
#  104,
#  2,
#  30,
#  20,
#  0,
#  0,
#  0,
#  4,
#  4,
#  3,
#  0,
#  0,
#  0,
#  5,
#  0,
#  9,
#  62,
#  20,
#  10,
#  3,
#  2,
#  0,
#  44,
#  3,
#  11,
#  5,
#  1,
#  0,
#  0,
#  5,
#  46,
#  0,
#  4,
#  6,
#  0,
#  4,
#  0,
#  4,
#  4,
#  0,
#  2,
#  1,
#  5,
# ...

# %%
pdf_pop_s1 = []
pdf_pop_s2 = []
for word in p:
    if p[word][0] <=10 and p[word][1] <= 10:
        continue
    else:
        pdf_pop_s1.append(p[word][0])
        pdf_pop_s2.append(p[word][1])

# %%
pul_pop = []
for word in p:
    pul_pop.append(p[word][0])

# %%
x=kstest(pul_pop,'norm')
print x
# Out:
# KstestResult(statistic=0.89570616797249514, pvalue=0.0)

# %%
xx = []
for i in range(len(pul_pop_s1)):
    if pdf_pop_s1[i] == 0 and pdf_pop_s2[i]!=0:
        pdf_pop_s1[i] = 1
    elif pdf_pop_s2[i] == 0 and pul_pop_s1[i]!=0:
        pul_pop_s2[i] = 1
    xx.append(pul_pop_s1[i]/pul_pop_s2[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-152-9fdc37c70e2e> in <module>()
#       1 xx = []
#       2 for i in range(len(pul_pop_s1)):
# ----> 3     if pdf_pop_s1[i] == 0 and pdf_pop_s2[i]!=0:
#       4         pdf_pop_s1[i] = 1
#       5     elif pdf_pop_s2[i] == 0 and pul_pop_s1[i]!=0:
#
# IndexError: list index out of range

# %%
from scipy.stats import kstest

# %%
from scipy.stats import ks_2samp

# %%
import numpy as np

import matplotlib.pyplot as plt

sorted_data = np.sort(x)

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)

plt.plot(sorted_data,yvals,'x')
plt.xscale('log')

plt.show()

# %%
yvals=np.arange(len(x))/float(len(x)-1)

# %%
c=np.arange(len(b))/float(len(b)-1)

# %%
a=[2,2,2,3,5,6,7,1]

# %%
for i in c:
    print i
# Out:
# 0.0
# 0.142857142857
# 0.285714285714
# 0.428571428571
# 0.571428571429
# 0.714285714286
# 0.857142857143
# 1.0

# %%
x=np.sort(a)

# %%
b
# Out:
# array([1, 2, 2, 2, 3, 5, 6, 7])

# %%
from __future__ import division

# %%
(1/8)*5+0.375
# Out:
# 1.0

# %%
y=[0.125,0.375,0.125,0.125,0.125,0.125]

# %%
x=set(x)

# %%
x
# Out:
# array([1, 2, 2, 2, 3, 5, 6, 7])

# %%
y=[]

# %%
for i in x:
    if len(y) == 0:
        y.append(a.count(i)/len(a))
    else:
        y.append((a.count(i)/len(a))+y[-1])

# %%
x
# Out:
# array([1, 2, 2, 2, 3, 5, 6, 7])

# %%
y
# Out:
# [0.125, 0.5, 0.625, 0.75, 0.875, 1.0]

# %%
plt.plot(list(x),y,'x')

# %%
plt.show()

# %%
x
# Out:
# array([1, 2, 2, 2, 3, 5, 6, 7])

# %%
plt.plot(x,yvals,'x')

# %%
plt.show()

# %%
a=[1,2,2,2,2,3,4,9,7]

# %%
b=set(a)

# %%
b
# Out:
# {1, 2, 3, 4, 7, 9}

# %%
c=ks_2samp(xy,xx)

# %%
c
# Out:
# Ks_2sampResult(statistic=0.1410088130508157, pvalue=1.073853679255828e-46)

# %%
n=1.073853679255828e-46

# %%
print "%f"%n
# Out:
# 0.000000

# %%
# Out:
# 0
